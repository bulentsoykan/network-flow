# %% [markdown]
# ![network.PNG](attachment:network.PNG)

# %%
Plant=["F1","F2"]
Warehouse=["WH1","WH2"]
Wholesaler=["WS1","WS2","WS3","WS4"]

# %%
supply={'F1': 400, 'F2': 250}
demand={'WS1': 200, 'WS2': 100, 'WS3': 150, 'WS4': 200}

# %%
cost_to_warehouse={
    ("F1","WH1"):40,
    ("F1","WH2"):35,
    ("F2","WH2"):25,
    ("F2","WH1"):0,
}

# %%
capacity_w1={
    ("F1","WH1"):250,
}

# %%
capacity_Plant={
    ("F2","WH1"):0,
}
